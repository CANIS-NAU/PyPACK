# %%
import sys
import pandas as pd
import libpypack
from libpypack.locations import map_locations
from libpypack.locations import webpage_locations
from libpypack.visualization import generate_maps
from libpypack.visualization import choropleth
from libpypack.visualization import heatmap
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### Predefine Paths for
# + Shapefile - The GeoDataset you wish to parse (i.e. a United States Shapefile)
# + CSV_FILE - The file you wish to extract information from

# %%
csv_file = "/Users/thatcher/Documents/GraduateSchool/Thesis/FORKS/PyPACK/notebooks/aggregate_political_file_500.csv"
shapefile = "/Users/thatcher/Documents/GraduateSchool/Thesis/FORKS/PyPACK/libpypack/examples/states_21basic/states.shp"

# %% [markdown]
# ### An Example of what a DataFrame could look like

# %%
location_dataframe = pd.read_csv(csv_file, sep="\t")
location_dataframe
# Out:
#       TweetID            Timestamp  \
# 0     1158127  2018-11-01 18:23:59
# 1    19458875  2018-11-09 07:52:44
# 2      949369  2018-11-01 16:31:25
# 3     3516929  2018-11-02 17:53:41
# 4    30497526  2018-11-14 08:55:51
# ..        ...                  ...
# 495  10544838  2018-11-05 14:06:40
# 496  19086970  2018-11-09 04:06:11
# 497  16373148  2018-11-07 23:28:38
# 498   5964188  2018-11-03 18:25:48
# 499  13226089  2018-11-06 15:51:56
#
#                                              Full_Text  In_Reply_To_User_ID  \
# 0    b'Alime Hay\xc4\xb1rl\xc4\xb1 Cumalar demi\xc5...                  NaN
# 1    b'#Kurallar\xc4\xb1mVarBenim sen se\xc3\xa7 be...                  NaN
# 2    b'\xf0\x9f\x8c\x8f TOP COUNTRIES TWEETING \xe2...                  NaN
# 3    b'@wqsley @notMigu @luanpereiradev @CdNLeon @S...         3.987787e+09
# 4    b'BREAKING: Democrat Josh Harder wins U.S. Hou...                  NaN
# ..                                                 ...                  ...
# 495  b'Remember this when you vote tomorrow. Rememb...                  NaN
# 496  b'TP-Link RE350 - Extensor de Red WiFi/rep... ...                  NaN
# 497  b'Protect Democracy is proud to be part of thi...                  NaN
# 498  b'@AndrewGillum is anti Israel and a liar...do...         4.650461e+08
# 499  b'YALL BETTER VOTE TODAY https://t.co/V3V4LBZdUM'                  NaN
#
#                  User_ID             User_Name User_Screen_Name  Coordinates  \
# 0             3065861716         @gülayşeçınar     GulayseCinar          NaN
# 1    1047345066459758592              Denizata  Denizat70197410          NaN
# 2     884648405754028032      💜SPEAK YOURSELF💜       Rose241293          NaN
# 3     901264397829537793            Brasileiro   PauloBCarneiro          NaN
# 4               19686263         Dr HerbSistah       Herbsistah          NaN
# ..                   ...                   ...              ...          ...
# 495             72983540   Anne Ward 🇬🇧💕🇺🇸MAGA       missward23          NaN
# 496           4098983295  OfertazonElectrónica  ofertazon_elect          NaN
# 497             49424457       Morgan Thompson          moliz30          NaN
# 498           4290843612              Sand03ss         SNafegar          NaN
# 499            715015530                £izzie  lizzie_johnson5          NaN
#
#     Place Bounding_Box     Quoted_Status_ID     Retweeted_Status  \
# 0     NaN           []                    0  1058022635697815556
# 1     NaN           []                    0                   []
# 2     NaN           []                    0  1058023718893498368
# 3     NaN           []                    0                   []
# 4     NaN           []                    0  1062533611751202817
# ..    ...          ...                  ...                  ...
# 495   NaN           []                    0  1059422757237280768
# 496   NaN           []                    0                   []
# 497   NaN           []  1060293408856723456  1060302660287500289
# 498   NaN           []  1058780939545919488                   []
# 499   NaN           []                    0                   []
#
#                    Hashtags                         URLs  \
# 0                        []                           []
# 1    ['KurallarımVarBenim']                           []
# 2       ['MAMAVOTE', 'BTS']                           []
# 3                        []                           []
# 4                        []                           []
# ..                      ...                          ...
# 495                      []                           []
# 496                      []  ['https://amzn.to/2tXGisF']
# 497                      []                           []
# 498                      []                           []
# 499                      []                           []
#
#                                          User_Mentions  \
# 0                 {'SeyhEdebali1': 903432832386813955}
# 1                                                   {}
# 2                {'btsvotingteam': 921338490775773184}
# 3    {'CdNLeon': 37312877, 'wqsley': 3987787245, 'f...
# 4                                     {'AP': 51241574}
# ..                                                 ...
# 495                        {'IrishVol69th': 616076314}
# 496                                                 {}
# 497            {'protctdemocracy': 819936721618038784}
# 498  {'RonDeSantisFL': 487297085, 'AndrewGillum': 4...
# 499                                                 {}
#
#                                                  Media Language
# 0                                                   []       tr
# 1                                                   []       tr
# 2                                                   []       en
# 3                                                   []       pt
# 4                                                   []       en
# ..                                                 ...      ...
# 495                                                 []       en
# 496  [{'id': 1060745339890814977, 'id_str': '106074...       es
# 497                                                 []       en
# 498                                                 []       en
# 499  [{'id': 1059835778446979072, 'id_str': '105983...       en
#
# [500 rows x 17 columns]

# %% [markdown]
# ### Generating/Extracting Files with Locations
#  + map_locations.location_df(csv_file):  Returns a DataFrame with extracted locations from text in the 'locs' column in the respected CSV/TSV
#  + generate_maps.get_loc_gdf(loc_df): Returns a GeoPandas Dataframe with parsed locations coordinates embedded in the Lattitude/Longitude Columns needed for GeoPandas

# %%
# Generate the Dataframe with Locations
loc_df = map_locations.locations_df(csv_file, sep="\t", output_dir="/Users/thatcher/Desktop", df_column="Full_Text")

# Generate the geoDataFrame with Lat/Lon Information
loc_gdf = generate_maps.get_loc_gdf(loc_df)
# Out:
# malformed node or string: <_ast.Name object at 0x109dce450>
# malformed node or string: <_ast.Name object at 0x20f50bc10>
# malformed node or string: <_ast.Name object at 0x20f50b9d0>
# malformed node or string: <_ast.Name object at 0x20f42cd50>
# malformed node or string: <_ast.Name object at 0x20f45e290>
# malformed node or string: <_ast.Name object at 0x20f45e250>
# malformed node or string: <_ast.Name object at 0x20f45e590>
# malformed node or string: <_ast.Name object at 0x20f45e790>
# malformed node or string: <_ast.Name object at 0x20f45e950>
# malformed node or string: <_ast.Name object at 0x20f45eb10>
# malformed node or string: <_ast.Name object at 0x20f45ecd0>
# malformed node or string: <_ast.Name object at 0x20f45ef10>
# malformed node or string: <_ast.Name object at 0x20f45d150>
# malformed node or string: <_ast.Name object at 0x20f45d350>
# malformed node or string: <_ast.Name object at 0x20f45d690>
# malformed node or string: <_ast.Name object at 0x20f45d850>
# malformed node or string: <_ast.Name object at 0x20f45da10>
# malformed node or string: <_ast.Name object at 0x20f45dbd0>
# malformed node or string: <_ast.Name object at 0x20f45ec50>
# malformed node or string: <_ast.Name object at 0x20f45e690>
# malformed node or string: <_ast.Name object at 0x20f45e410>
# malformed node or string: <_ast.Name object at 0x20f42cd50>
# malformed node or string: <_ast.Name object at 0x20f42c610>
# malformed node or string: <_ast.Name object at 0x20f45ea10>
# malformed node or string: <_ast.Name object at 0x20f45ec90>
# malformed node or string: <_ast.Name object at 0x20f45e290>
# malformed node or string: <_ast.Name object at 0x20f45e7d0>
# malformed node or string: <_ast.Name object at 0x20f42c510>
# malformed node or string: <_ast.Name object at 0x133e69cd0>
# malformed node or string: <_ast.Name object at 0x20f45e7d0>
# malformed node or string: <_ast.Name object at 0x20f45ed90>
# malformed node or string: <_ast.Name object at 0x109dce4d0>
# malformed node or string: <_ast.Name object at 0x20f50bc90>
# malformed node or string: <_ast.Name object at 0x20f50bc50>
# malformed node or string: <_ast.Name object at 0x20f45d310>
# malformed node or string: <_ast.Name object at 0x20f45d690>
# malformed node or string: <_ast.Name object at 0x20f45d510>
# malformed node or string: <_ast.Name object at 0x20f45d910>
# malformed node or string: <_ast.Name object at 0x20f45d590>
# malformed node or string: <_ast.Name object at 0x20f45d090>
# malformed node or string: <_ast.Name object at 0x20f45df50>
# malformed node or string: <_ast.Name object at 0x133f4f050>
# malformed node or string: <_ast.Name object at 0x20f45d0d0>
# malformed node or string: <_ast.Name object at 0x20f45d410>
# malformed node or string: <_ast.Name object at 0x20f45da50>
# malformed node or string: <_ast.Name object at 0x20f50bad0>
# malformed node or string: <_ast.Name object at 0x133f4f110>
# malformed node or string: <_ast.Name object at 0x133f4f350>
# malformed node or string: <_ast.Name object at 0x133f4f590>
# malformed node or string: <_ast.Name object at 0x20f45d550>
# malformed node or string: <_ast.Name object at 0x133f4f590>
# malformed node or string: <_ast.Name object at 0x133f4f190>
# malformed node or string: <_ast.Name object at 0x133f4f890>
# malformed node or string: <_ast.Name object at 0x133f4fa90>
# malformed node or string: <_ast.Name object at 0x133f4fc50>
# malformed node or string: <_ast.Name object at 0x133f4fe10>
# malformed node or string: <_ast.Name object at 0x133f5b090>
# malformed node or string: <_ast.Name object at 0x133f5b3d0>
# malformed node or string: <_ast.Name object at 0x133f5b4d0>
# malformed node or string: <_ast.Name object at 0x133f5b6d0>
# malformed node or string: <_ast.Name object at 0x133f5b890>
# malformed node or string: <_ast.Name object at 0x133f4f8d0>
# malformed node or string: <_ast.Name object at 0x133f5b210>
# malformed node or string: <_ast.Name object at 0x133f5b710>
# malformed node or string: <_ast.Name object at 0x133f5b310>
# malformed node or string: <_ast.Name object at 0x133f5b950>
# malformed node or string: <_ast.Name object at 0x133f5bb10>
# malformed node or string: <_ast.Name object at 0x133f5bcd0>
# malformed node or string: <_ast.Name object at 0x133f5bf50>
# malformed node or string: <_ast.Name object at 0x133f4d350>
# malformed node or string: <_ast.Name object at 0x133f4d690>
# malformed node or string: <_ast.Name object at 0x133f4d790>
# malformed node or string: <_ast.Name object at 0x133f4d990>
# malformed node or string: <_ast.Name object at 0x133f4db50>
# malformed node or string: <_ast.Name object at 0x133f4df10>
# malformed node or string: <_ast.Name object at 0x133f4db50>
# malformed node or string: <_ast.Name object at 0x133f4dad0>
# malformed node or string: <_ast.Name object at 0x133f4d350>
# malformed node or string: <_ast.Name object at 0x133f5bf90>
# malformed node or string: <_ast.Name object at 0x133f5b110>
# malformed node or string: <_ast.Name object at 0x133f5b8d0>
# malformed node or string: <_ast.Name object at 0x133f5b290>
# malformed node or string: <_ast.Name object at 0x133f5b1d0>
# malformed node or string: <_ast.Name object at 0x133f4f950>
# malformed node or string: <_ast.Name object at 0x133f4fdd0>
# malformed node or string: <_ast.Name object at 0x133f4fd50>
# malformed node or string: <_ast.Name object at 0x133f4f6d0>
# malformed node or string: <_ast.Name object at 0x133f4f510>
# malformed node or string: <_ast.Name object at 0x133f4f150>
# malformed node or string: <_ast.Name object at 0x20f45d0d0>
# malformed node or string: <_ast.Name object at 0x20f45d6d0>
# malformed node or string: <_ast.Name object at 0x20f45ded0>
# malformed node or string: <_ast.Name object at 0x20f45d050>
# malformed node or string: <_ast.Name object at 0x133f4d8d0>
# malformed node or string: <_ast.Name object at 0x133f4de50>
# malformed node or string: <_ast.Name object at 0x133f4d890>
# malformed node or string: <_ast.Name object at 0x133f4d150>
# malformed node or string: <_ast.Name object at 0x133f5b990>
# malformed node or string: <_ast.Name object at 0x133f5b4d0>
# malformed node or string: <_ast.Name object at 0x133f4f150>
# malformed node or string: <_ast.Name object at 0x133f4f550>
# malformed node or string: <_ast.Name object at 0x133f4fd10>
# malformed node or string: <_ast.Name object at 0x133f4f8d0>
# malformed node or string: <_ast.Name object at 0x20f45df50>
# malformed node or string: <_ast.Name object at 0x20f45d7d0>
# malformed node or string: <_ast.Name object at 0x20f45d850>
# malformed node or string: <_ast.Name object at 0x20f50bd10>
# malformed node or string: <_ast.Name object at 0x20f50be50>
# malformed node or string: <_ast.Name object at 0x1cbbc62d0>
# malformed node or string: <_ast.Name object at 0x20f42c990>
# malformed node or string: <_ast.Name object at 0x20f42c190>
# malformed node or string: <_ast.Name object at 0x20f44ef90>
# malformed node or string: <_ast.Name object at 0x20f45e310>
# malformed node or string: <_ast.Name object at 0x20f45eb10>
# malformed node or string: <_ast.Name object at 0x20f50bd10>
# malformed node or string: <_ast.Name object at 0x20f45d9d0>
# malformed node or string: <_ast.Name object at 0x20f45d610>
# malformed node or string: <_ast.Name object at 0x133f4ff90>
# malformed node or string: <_ast.Name object at 0x133f5b510>
# malformed node or string: <_ast.Name object at 0x133f4d690>
# malformed node or string: <_ast.Name object at 0x133f4d350>
# malformed node or string: <_ast.Name object at 0x20f45e090>
# malformed node or string: <_ast.Name object at 0x20f45ea10>
# malformed node or string: <_ast.Name object at 0x20f45ebd0>
# malformed node or string: <_ast.Name object at 0x133f50110>
# malformed node or string: <_ast.Name object at 0x133f50310>
# malformed node or string: <_ast.Name object at 0x133f504d0>
# malformed node or string: <_ast.Name object at 0x133f50690>
# malformed node or string: <_ast.Name object at 0x133f50850>
# malformed node or string: <_ast.Name object at 0x133f50a10>
# malformed node or string: <_ast.Name object at 0x133f50bd0>
# malformed node or string: <_ast.Name object at 0x133f50d90>
# malformed node or string: <_ast.Name object at 0x20f5142d0>
# malformed node or string: <_ast.Name object at 0x133f50ed0>
# malformed node or string: <_ast.Name object at 0x133f50c90>
# malformed node or string: <_ast.Name object at 0x133f509d0>
# malformed node or string: <_ast.Name object at 0x133f50810>
# malformed node or string: <_ast.Name object at 0x133f504d0>
# malformed node or string: <_ast.Name object at 0x133f503d0>
# malformed node or string: <_ast.Name object at 0x20f45ebd0>
# malformed node or string: <_ast.Name object at 0x20f45ef10>
# malformed node or string: <_ast.Name object at 0x20f45efd0>
# malformed node or string: <_ast.Name object at 0x20f45eb10>
# malformed node or string: <_ast.Name object at 0x20f45e7d0>
# malformed node or string: <_ast.Name object at 0x1cbb9d9d0>
# malformed node or string: <_ast.Name object at 0x20f42c4d0>
# malformed node or string: <_ast.Name object at 0x20f42cd50>
# malformed node or string: <_ast.Name object at 0x1cbbc62d0>
# malformed node or string: <_ast.Name object at 0x20f50bf50>
# malformed node or string: <_ast.Name object at 0x20f50be50>
# malformed node or string: <_ast.Name object at 0x133e69150>
# malformed node or string: <_ast.Name object at 0x20f45d790>
# malformed node or string: <_ast.Name object at 0x20f45dd50>
# malformed node or string: <_ast.Name object at 0x20f45d150>
# malformed node or string: <_ast.Name object at 0x20f45dc50>
# malformed node or string: <_ast.Name object at 0x20f45da50>
# malformed node or string: <_ast.Name object at 0x20f45d990>
# malformed node or string: <_ast.Name object at 0x20f45d4d0>
# malformed node or string: <_ast.Name object at 0x133f4f510>
# malformed node or string: <_ast.Name object at 0x133f4f1d0>
# malformed node or string: <_ast.Name object at 0x133f4f4d0>
# malformed node or string: <_ast.Name object at 0x133f4f490>
# malformed node or string: <_ast.Name object at 0x133f4fed0>
# malformed node or string: <_ast.Name object at 0x133f4fa50>
# malformed node or string: <_ast.Name object at 0x133f5b750>
# malformed node or string: <_ast.Name object at 0x133f5b150>
# malformed node or string: <_ast.Name object at 0x133f4f990>
# malformed node or string: <_ast.Name object at 0x133f4f1d0>
# malformed node or string: <_ast.Name object at 0x133f4ff90>
# malformed node or string: <_ast.Name object at 0x20f45dc50>
# malformed node or string: <_ast.Name object at 0x20f45d510>
# malformed node or string: <_ast.Name object at 0x20f45d490>
# malformed node or string: <_ast.Name object at 0x20f50be50>
# malformed node or string: <_ast.Name object at 0x20f50bd10>
# malformed node or string: <_ast.Name object at 0x20f42c690>
# malformed node or string: <_ast.Name object at 0x20f45eb10>
# malformed node or string: <_ast.Name object at 0x20f45ed50>
# malformed node or string: <_ast.Name object at 0x20f45e550>
# malformed node or string: <_ast.Name object at 0x133f5b150>
# malformed node or string: <_ast.Name object at 0x133f5bf90>
# malformed node or string: <_ast.Name object at 0x133f5b190>
# malformed node or string: <_ast.Name object at 0x133f5bbd0>
# malformed node or string: <_ast.Name object at 0x133f4db50>
# malformed node or string: <_ast.Name object at 0x133f4ddd0>
# malformed node or string: <_ast.Name object at 0x133f4d950>
# malformed node or string: <_ast.Name object at 0x133f4d4d0>
# malformed node or string: <_ast.Name object at 0x133f4d310>
# malformed node or string: <_ast.Name object at 0x133f4d710>
# malformed node or string: <_ast.Name object at 0x133f4dad0>
# malformed node or string: <_ast.Name object at 0x133f4d3d0>
# malformed node or string: <_ast.Name object at 0x133f4d150>
# malformed node or string: <_ast.Name object at 0x133e69150>
# malformed node or string: <_ast.Name object at 0x133f5b590>
# malformed node or string: <_ast.Name object at 0x133f5b490>
# malformed node or string: <_ast.Name object at 0x133f5bd10>
# malformed node or string: <_ast.Name object at 0x133f5b910>
# malformed node or string: <_ast.Name object at 0x133f4ff90>
# malformed node or string: <_ast.Name object at 0x133f4fa10>
# malformed node or string: <_ast.Name object at 0x133f4f290>
# malformed node or string: <_ast.Name object at 0x133f4ffd0>
# malformed node or string: <_ast.Name object at 0x133f4df10>
# malformed node or string: <_ast.Name object at 0x133f4d310>
# malformed node or string: <_ast.Name object at 0x133f4df50>
# malformed node or string: <_ast.Name object at 0x133f5b3d0>
# malformed node or string: <_ast.Name object at 0x133f5bc10>
# malformed node or string: <_ast.Name object at 0x133f5b850>
# malformed node or string: <_ast.Name object at 0x133e69150>
# malformed node or string: <_ast.Name object at 0x133f4f110>
# malformed node or string: <_ast.Name object at 0x133f4fdd0>
# malformed node or string: <_ast.Name object at 0x133f4f850>
# malformed node or string: <_ast.Name object at 0x20f45d450>
# malformed node or string: <_ast.Name object at 0x20f45d8d0>
# malformed node or string: <_ast.Name object at 0x20f45d390>
# malformed node or string: <_ast.Name object at 0x20f45dd90>
# malformed node or string: <_ast.Name object at 0x20f45d5d0>
# malformed node or string: <_ast.Name object at 0x20f45d350>
# malformed node or string: <_ast.Name object at 0x20f50b750>
# malformed node or string: <_ast.Name object at 0x20f50bc90>
# malformed node or string: <_ast.Name object at 0x20f42cb10>
# malformed node or string: <_ast.Name object at 0x20f42c150>
# malformed node or string: <_ast.Name object at 0x20f45e490>
# malformed node or string: <_ast.Name object at 0x20f45efd0>
# malformed node or string: <_ast.Name object at 0x20f45e910>
# malformed node or string: <_ast.Name object at 0x20f45ee50>
# malformed node or string: <_ast.Name object at 0x133f50290>
# malformed node or string: <_ast.Name object at 0x20f45ead0>
# malformed node or string: <_ast.Name object at 0x20f50b850>
# malformed node or string: <_ast.Name object at 0x20f45dd90>
# malformed node or string: <_ast.Name object at 0x20f45d950>
# malformed node or string: <_ast.Name object at 0x133e69150>
# malformed node or string: <_ast.Name object at 0x133f4f250>
# malformed node or string: <_ast.Name object at 0x133f4ff50>
# malformed node or string: <_ast.Name object at 0x133f5bc10>
# malformed node or string: <_ast.Name object at 0x133f5ba90>
# malformed node or string: <_ast.Name object at 0x133f4d610>
# malformed node or string: <_ast.Name object at 0x133f50090>
# malformed node or string: <_ast.Name object at 0x133f50910>
# malformed node or string: <_ast.Name object at 0x133f50150>
# malformed node or string: <_ast.Name object at 0x133f50ed0>
# malformed node or string: <_ast.Name object at 0x133f50a90>
# malformed node or string: <_ast.Name object at 0x133f50f10>
# malformed node or string: <_ast.Name object at 0x20f5145d0>
# malformed node or string: <_ast.Name object at 0x20f5141d0>
# malformed node or string: <_ast.Name object at 0x20f514550>
# malformed node or string: <_ast.Name object at 0x20f514810>
# malformed node or string: <_ast.Name object at 0x20f5149d0>
# malformed node or string: <_ast.Name object at 0x20f514b90>
# malformed node or string: <_ast.Name object at 0x20f514d50>
# malformed node or string: <_ast.Name object at 0x20f514f10>
# malformed node or string: <_ast.Name object at 0x20f51a610>
# malformed node or string: <_ast.Name object at 0x20f514ad0>
# malformed node or string: <_ast.Name object at 0x20f514750>
# malformed node or string: <_ast.Name object at 0x133f50f50>
# malformed node or string: <_ast.Name object at 0x133f50490>
# malformed node or string: <_ast.Name object at 0x133f50190>
# malformed node or string: <_ast.Name object at 0x133f50790>
# malformed node or string: <_ast.Name object at 0x20f514b10>
# malformed node or string: <_ast.Name object at 0x20f514d90>
# malformed node or string: <_ast.Name object at 0x20f514850>
# malformed node or string: <_ast.Name object at 0x20f514250>
# malformed node or string: <_ast.Name object at 0x133e69150>
# malformed node or string: <_ast.Name object at 0x133f50e90>
# malformed node or string: <_ast.Name object at 0x133f50f10>
# malformed node or string: <_ast.Name object at 0x133f50fd0>
# malformed node or string: <_ast.Name object at 0x20f45e810>
# malformed node or string: <_ast.Name object at 0x20f45eb10>
# malformed node or string: <_ast.Name object at 0x20f45ee50>
# malformed node or string: <_ast.Name object at 0x20f45ec90>
# malformed node or string: <_ast.Name object at 0x20f45e1d0>
# malformed node or string: <_ast.Name object at 0x20f45e310>
# malformed node or string: <_ast.Name object at 0x20f42c510>
# malformed node or string: <_ast.Name object at 0x20f42c4d0>
# malformed node or string: <_ast.Name object at 0x20f50b850>
# malformed node or string: <_ast.Name object at 0x20f50bf50>
# malformed node or string: <_ast.Name object at 0x20f45d490>
# malformed node or string: <_ast.Name object at 0x20f45de50>
# malformed node or string: <_ast.Name object at 0x20f45d2d0>
# malformed node or string: <_ast.Name object at 0x20f45db90>
# malformed node or string: <_ast.Name object at 0x20f45d250>
# malformed node or string: <_ast.Name object at 0x20f45d3d0>
# malformed node or string: <_ast.Name object at 0x20f45d550>
# malformed node or string: <_ast.Name object at 0x133f4fcd0>
# malformed node or string: <_ast.Name object at 0x133f4f5d0>
# malformed node or string: <_ast.Name object at 0x133f4f050>
# malformed node or string: <_ast.Name object at 0x133f4f550>
# malformed node or string: <_ast.Name object at 0x133f4f410>
# malformed node or string: <_ast.Name object at 0x133f4fa10>
# malformed node or string: <_ast.Name object at 0x133f5b410>
# malformed node or string: <_ast.Name object at 0x133f4f710>
# malformed node or string: <_ast.Name object at 0x133f4f750>
# malformed node or string: <_ast.Name object at 0x1cbb9d9d0>
# malformed node or string: <_ast.Name object at 0x20f45d610>
# malformed node or string: <_ast.Name object at 0x20f45d190>
# malformed node or string: <_ast.Name object at 0x20f45d350>
# malformed node or string: <_ast.Name object at 0x20f42ca10>
# malformed node or string: <_ast.Name object at 0x20f45e090>
# malformed node or string: <_ast.Name object at 0x20f45ee50>
# malformed node or string: <_ast.Name object at 0x133f50a50>
# malformed node or string: <_ast.Name object at 0x133f50f90>
# malformed node or string: <_ast.Name object at 0x20f45e990>
# malformed node or string: <_ast.Name object at 0x20f45d490>
# malformed node or string: <_ast.Name object at 0x133f4f1d0>

# %% [markdown]
# ### Heatmap
#
# + heatmap.heatmap(loc_gdf): Writes to a file labeled 'heatmap.html' to the location defined by 'output_dir'. It also returns a Heatmap defined in Folium (which you can call to see the map)

# %%
# Generate the heatmap
hmap = heatmap.heatmap(loc_gdf, output_dir="/Users/thatcher/Desktop")

# Display the heatmap
hmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Choropleth Map Generation
#
# + choropleth.choropleth_map(loc_gdf): Returns a GeoPandas Object with additional columns that is needed for plotting this map.
#
# + choropleth.plot_map(gdf): Writes an image called "choropleth.png" to your respected output_dir and returns a map that is displayable.

# %%
# Generate the Choropleth Map
gdf = choropleth.choropleth_map(loc_gdf, shp_path="/Users/thatcher/Documents/GraduateSchool/Thesis/FORKS/PyPACK/libpypack/examples/states_21basic/states.shp")

# Plot the choropleth map
plot = choropleth.plot_map(gdf, output_dir="/Users/thatcher/Desktop")

# %% [markdown]
# ### Generation of Overlay Map
# + generate_maps.generate_overlay_gdf(loc_df): Given a shapefile for the field 'shp_file' and a dataframe with locations added on. It generates a GeoPandas for both the shapefile and location dataframe that it was passed, which you then need to pass on to the next funciton.
# + generate_maps.plot_gdf(gdf, loc_gdf): Returns an image named "overlay.png" to the output_dir you specify and returns a plot that is displayable.

# %%
# Generate the Location Overlay Map
gdf, loc_gdf = generate_maps.generate_overlay_gdf(loc_df, filename="/Users/thatcher/Documents/GraduateSchool/Thesis/FORKS/PyPACK/libpypack/examples/states_21basic/states.shp")

# Plot the Overlay Map
plot = generate_maps.plot_gdf(gdf, loc_gdf, filepath="/Users/thatcher/Desktop")
# Out:
# malformed node or string: <_ast.Name object at 0x1cb702d10>
# malformed node or string: <_ast.Name object at 0x1cb702910>
# malformed node or string: <_ast.Name object at 0x1cb726f50>
# malformed node or string: <_ast.Name object at 0x1cb7b9a10>
# malformed node or string: <_ast.Name object at 0x1cb7c6cd0>
# malformed node or string: <_ast.Name object at 0x1cb7c6c90>
# malformed node or string: <_ast.Name object at 0x1cb7c6890>
# malformed node or string: <_ast.Name object at 0x1cb7cbe50>
# malformed node or string: <_ast.Name object at 0x1cb630dd0>
# malformed node or string: <_ast.Name object at 0x1cb7d5cd0>
# malformed node or string: <_ast.Name object at 0x1cb7dc850>
# malformed node or string: <_ast.Name object at 0x1cb705c10>
# malformed node or string: <_ast.Name object at 0x1cb6af450>
# malformed node or string: <_ast.Name object at 0x1cb62a510>
# malformed node or string: <_ast.Name object at 0x1cb711610>
# malformed node or string: <_ast.Name object at 0x1cb70e1d0>
# malformed node or string: <_ast.Name object at 0x1cb55ee90>
# malformed node or string: <_ast.Name object at 0x1cb6359d0>
# malformed node or string: <_ast.Name object at 0x1cb4c6cd0>
# malformed node or string: <_ast.Name object at 0x1cb70f8d0>
# malformed node or string: <_ast.Name object at 0x1cb56a550>
# malformed node or string: <_ast.Name object at 0x1cb56ab50>
# malformed node or string: <_ast.Name object at 0x1cb4d2f90>
# malformed node or string: <_ast.Name object at 0x1cb4d2190>
# malformed node or string: <_ast.Name object at 0x1cb4d2090>
# malformed node or string: <_ast.Name object at 0x1cb4cb8d0>
# malformed node or string: <_ast.Name object at 0x1cb4cb290>
# malformed node or string: <_ast.Name object at 0x1cb4cbf10>
# malformed node or string: <_ast.Name object at 0x1cb4c8110>
# malformed node or string: <_ast.Name object at 0x1cb4c9390>
# malformed node or string: <_ast.Name object at 0x1cb643f90>
# malformed node or string: <_ast.Name object at 0x1cb4c57d0>
# malformed node or string: <_ast.Name object at 0x1cb4c2710>
# malformed node or string: <_ast.Name object at 0x1cb561310>
# malformed node or string: <_ast.Name object at 0x1cb563b10>
# malformed node or string: <_ast.Name object at 0x1cb7de110>
# malformed node or string: <_ast.Name object at 0x1cb7e5350>
# malformed node or string: <_ast.Name object at 0x1cb7e5c90>
# malformed node or string: <_ast.Name object at 0x20f50bad0>
# malformed node or string: <_ast.Name object at 0x1cb4c2090>
# malformed node or string: <_ast.Name object at 0x1cb4c96d0>
# malformed node or string: <_ast.Name object at 0x1cb643790>
# malformed node or string: <_ast.Name object at 0x1cb4cb550>
# malformed node or string: <_ast.Name object at 0x1cb4c1950>
# malformed node or string: <_ast.Name object at 0x1cb4d23d0>
# malformed node or string: <_ast.Name object at 0x1cb4d2f50>
# malformed node or string: <_ast.Name object at 0x1cb629f90>
# malformed node or string: <_ast.Name object at 0x1cb7071d0>
# malformed node or string: <_ast.Name object at 0x1cb6af450>
# malformed node or string: <_ast.Name object at 0x1cb7d54d0>
# malformed node or string: <_ast.Name object at 0x1cb7c66d0>
# malformed node or string: <_ast.Name object at 0x1cb7c6690>
# malformed node or string: <_ast.Name object at 0x1cb7bb350>
# malformed node or string: <_ast.Name object at 0x1cb703e90>
# malformed node or string: <_ast.Name object at 0x1cb722ed0>
# malformed node or string: <_ast.Name object at 0x1cb702c90>
# malformed node or string: <_ast.Name object at 0x1cb7eb850>
# malformed node or string: <_ast.Name object at 0x20f50b6d0>
# malformed node or string: <_ast.Name object at 0x1cb63ea10>
# malformed node or string: <_ast.Name object at 0x1cb640690>
# malformed node or string: <_ast.Name object at 0x1cb63ba10>
# malformed node or string: <_ast.Name object at 0x1cb8135d0>
# malformed node or string: <_ast.Name object at 0x20f45e210>
# malformed node or string: <_ast.Name object at 0x20f45e7d0>
# malformed node or string: <_ast.Name object at 0x1cb7ff350>
# malformed node or string: <_ast.Name object at 0x1cb7d1450>
# malformed node or string: <_ast.Name object at 0x1cb7d1e10>
# malformed node or string: <_ast.Name object at 0x1cb7d1d90>
# malformed node or string: <_ast.Name object at 0x1cb7d14d0>
# malformed node or string: <_ast.Name object at 0x1c6982250>
# malformed node or string: <_ast.Name object at 0x1c6980390>
# malformed node or string: <_ast.Name object at 0x1c6975310>
# malformed node or string: <_ast.Name object at 0x133c877d0>
# malformed node or string: <_ast.Name object at 0x1c697f750>
# malformed node or string: <_ast.Name object at 0x133e3a990>
# malformed node or string: <_ast.Name object at 0x133d3ba50>
# malformed node or string: <_ast.Name object at 0x1c6967a90>
# malformed node or string: <_ast.Name object at 0x133f64ed0>
# malformed node or string: <_ast.Name object at 0x133f64f90>
# malformed node or string: <_ast.Name object at 0x133cc3c10>
# malformed node or string: <_ast.Name object at 0x133f64f50>
# malformed node or string: <_ast.Name object at 0x1c6967a90>
# malformed node or string: <_ast.Name object at 0x133d41290>
# malformed node or string: <_ast.Name object at 0x133e2bbd0>
# malformed node or string: <_ast.Name object at 0x133c87410>
# malformed node or string: <_ast.Name object at 0x1c6980b10>
# malformed node or string: <_ast.Name object at 0x1cb7d1d90>
# malformed node or string: <_ast.Name object at 0x1cb7d1390>
# malformed node or string: <_ast.Name object at 0x20f45ea10>
# malformed node or string: <_ast.Name object at 0x1cb8135d0>
# malformed node or string: <_ast.Name object at 0x1cb63ea90>
# malformed node or string: <_ast.Name object at 0x1cb7e5c90>
# malformed node or string: <_ast.Name object at 0x1cb722bd0>
# malformed node or string: <_ast.Name object at 0x1cb703190>
# malformed node or string: <_ast.Name object at 0x1cb7bea50>
# malformed node or string: <_ast.Name object at 0x1cb7ca150>
# malformed node or string: <_ast.Name object at 0x1cb705210>
# malformed node or string: <_ast.Name object at 0x133e3a990>
# malformed node or string: <_ast.Name object at 0x1c697fb10>
# malformed node or string: <_ast.Name object at 0x133e39390>
# malformed node or string: <_ast.Name object at 0x1c6957510>
# malformed node or string: <_ast.Name object at 0x1c69822d0>
# malformed node or string: <_ast.Name object at 0x1cb7d1190>
# malformed node or string: <_ast.Name object at 0x20f45e910>
# malformed node or string: <_ast.Name object at 0x20f45e950>
# malformed node or string: <_ast.Name object at 0x1cb8134d0>
# malformed node or string: <_ast.Name object at 0x1cb640690>
# malformed node or string: <_ast.Name object at 0x1cb63ea10>
# malformed node or string: <_ast.Name object at 0x1cb7bb350>
# malformed node or string: <_ast.Name object at 0x1cb629c10>
# malformed node or string: <_ast.Name object at 0x1cb7e54d0>
# malformed node or string: <_ast.Name object at 0x1cb7de810>
# malformed node or string: <_ast.Name object at 0x1cb4c4d50>
# malformed node or string: <_ast.Name object at 0x1cb711610>
# malformed node or string: <_ast.Name object at 0x1cb7e58d0>
# malformed node or string: <_ast.Name object at 0x1cb7d9990>
# malformed node or string: <_ast.Name object at 0x1cb63e310>
# malformed node or string: <_ast.Name object at 0x1cb6400d0>
# malformed node or string: <_ast.Name object at 0x1cb7d17d0>
# malformed node or string: <_ast.Name object at 0x1cb4c4650>
# malformed node or string: <_ast.Name object at 0x1cb7d1f50>
# malformed node or string: <_ast.Name object at 0x1c6957190>
# malformed node or string: <_ast.Name object at 0x133c87090>
# malformed node or string: <_ast.Name object at 0x1cb7051d0>
# malformed node or string: <_ast.Name object at 0x1cb7dce50>
# malformed node or string: <_ast.Name object at 0x1cb7d5450>
# malformed node or string: <_ast.Name object at 0x1cb630e10>
# malformed node or string: <_ast.Name object at 0x1cb7ca790>
# malformed node or string: <_ast.Name object at 0x1cb7c6d50>
# malformed node or string: <_ast.Name object at 0x1cb7c6850>
# malformed node or string: <_ast.Name object at 0x1cb7c6710>
# malformed node or string: <_ast.Name object at 0x1cb703e90>
# malformed node or string: <_ast.Name object at 0x1cb702290>
# malformed node or string: <_ast.Name object at 0x1cb6ae990>
# malformed node or string: <_ast.Name object at 0x1cb70e610>
# malformed node or string: <_ast.Name object at 0x1cb56ab10>
# malformed node or string: <_ast.Name object at 0x1cb4c6650>
# malformed node or string: <_ast.Name object at 0x1cb70f8d0>
# malformed node or string: <_ast.Name object at 0x1cb4d26d0>
# malformed node or string: <_ast.Name object at 0x1cb4c8f50>
# malformed node or string: <_ast.Name object at 0x1cb4cb450>
# malformed node or string: <_ast.Name object at 0x1cb4cb5d0>
# malformed node or string: <_ast.Name object at 0x1cb4cba50>
# malformed node or string: <_ast.Name object at 0x1cb4d2d10>
# malformed node or string: <_ast.Name object at 0x1cb70f890>
# malformed node or string: <_ast.Name object at 0x1cb4c6290>
# malformed node or string: <_ast.Name object at 0x1cb56a550>
# malformed node or string: <_ast.Name object at 0x10c03ac90>
# malformed node or string: <_ast.Name object at 0x1cb702290>
# malformed node or string: <_ast.Name object at 0x1cb702450>
# malformed node or string: <_ast.Name object at 0x1cb7d52d0>
# malformed node or string: <_ast.Name object at 0x133e3a550>
# malformed node or string: <_ast.Name object at 0x1cb712510>
# malformed node or string: <_ast.Name object at 0x1cb707250>
# malformed node or string: <_ast.Name object at 0x1cb7dee50>
# malformed node or string: <_ast.Name object at 0x1cb7ea2d0>
# malformed node or string: <_ast.Name object at 0x20f2431d0>
# malformed node or string: <_ast.Name object at 0x133d40750>
# malformed node or string: <_ast.Name object at 0x133d3e8d0>
# malformed node or string: <_ast.Name object at 0x1cb7dc890>
# malformed node or string: <_ast.Name object at 0x1cb631890>
# malformed node or string: <_ast.Name object at 0x1cb7c6d90>
# malformed node or string: <_ast.Name object at 0x1cb7bd210>
# malformed node or string: <_ast.Name object at 0x1cb7b9950>
# malformed node or string: <_ast.Name object at 0x1cbd532d0>
# malformed node or string: <_ast.Name object at 0x1cb7e5b90>
# malformed node or string: <_ast.Name object at 0x1cb7e5c10>
# malformed node or string: <_ast.Name object at 0x20f50bad0>
# malformed node or string: <_ast.Name object at 0x1cb640690>
# malformed node or string: <_ast.Name object at 0x1cb813ad0>
# malformed node or string: <_ast.Name object at 0x1cb708350>
# malformed node or string: <_ast.Name object at 0x1cb7ff0d0>
# malformed node or string: <_ast.Name object at 0x133ccb650>
# malformed node or string: <_ast.Name object at 0x1cb7d1950>
# malformed node or string: <_ast.Name object at 0x1cb7d1a90>
# malformed node or string: <_ast.Name object at 0x1cb7d11d0>
# malformed node or string: <_ast.Name object at 0x1cb8a6e50>
# malformed node or string: <_ast.Name object at 0x1c697eed0>
# malformed node or string: <_ast.Name object at 0x133d3ba50>
# malformed node or string: <_ast.Name object at 0x1c6965390>
# malformed node or string: <_ast.Name object at 0x133f64f10>
# malformed node or string: <_ast.Name object at 0x1cb4cb890>
# malformed node or string: <_ast.Name object at 0x1cb4c5ed0>
# malformed node or string: <_ast.Name object at 0x1cb643710>
# malformed node or string: <_ast.Name object at 0x1cb4c2710>
# malformed node or string: <_ast.Name object at 0x1cb4c3c10>
# malformed node or string: <_ast.Name object at 0x1cb56f4d0>
# malformed node or string: <_ast.Name object at 0x1cb5639d0>
# malformed node or string: <_ast.Name object at 0x1cb4c3810>
# malformed node or string: <_ast.Name object at 0x1cb643f10>
# malformed node or string: <_ast.Name object at 0x133cc3b50>
# malformed node or string: <_ast.Name object at 0x1cb4cb450>
# malformed node or string: <_ast.Name object at 0x133f64b50>
# malformed node or string: <_ast.Name object at 0x133d41e90>
# malformed node or string: <_ast.Name object at 0x1c697fad0>
# malformed node or string: <_ast.Name object at 0x1c6982710>
# malformed node or string: <_ast.Name object at 0x133ccb650>
# malformed node or string: <_ast.Name object at 0x1cb7d1450>
# malformed node or string: <_ast.Name object at 0x1cb7ff110>
# malformed node or string: <_ast.Name object at 0x1cb7e5450>
# malformed node or string: <_ast.Name object at 0x1c67d42d0>
# malformed node or string: <_ast.Name object at 0x1cb7036d0>
# malformed node or string: <_ast.Name object at 0x1cb4c4d50>
# malformed node or string: <_ast.Name object at 0x20f45e7d0>
# malformed node or string: <_ast.Name object at 0x1cb4c1950>
# malformed node or string: <_ast.Name object at 0x1cb7d9990>
# malformed node or string: <_ast.Name object at 0x1cb7d5c90>
# malformed node or string: <_ast.Name object at 0x1cb702090>
# malformed node or string: <_ast.Name object at 0x1cb7f0890>
# malformed node or string: <_ast.Name object at 0x1cb4d26d0>
# malformed node or string: <_ast.Name object at 0x133cbfe50>
# malformed node or string: <_ast.Name object at 0x133ca0b50>
# malformed node or string: <_ast.Name object at 0x133ca2210>
# malformed node or string: <_ast.Name object at 0x133caa290>
# malformed node or string: <_ast.Name object at 0x133caa750>
# malformed node or string: <_ast.Name object at 0x133ca6ed0>
# malformed node or string: <_ast.Name object at 0x133ca3410>
# malformed node or string: <_ast.Name object at 0x133cb6b50>
# malformed node or string: <_ast.Name object at 0x133cb6b90>
# malformed node or string: <_ast.Name object at 0x133c7c9d0>
# malformed node or string: <_ast.Name object at 0x133c7cd50>
# malformed node or string: <_ast.Name object at 0x133c7c410>
# malformed node or string: <_ast.Name object at 0x133cb3210>
# malformed node or string: <_ast.Name object at 0x133cb3650>
# malformed node or string: <_ast.Name object at 0x1c696bd90>
# malformed node or string: <_ast.Name object at 0x1c696b850>
# malformed node or string: <_ast.Name object at 0x1c695b4d0>
# malformed node or string: <_ast.Name object at 0x1c6987790>
# malformed node or string: <_ast.Name object at 0x1c696b6d0>
# malformed node or string: <_ast.Name object at 0x1c696b4d0>
# malformed node or string: <_ast.Name object at 0x133c91d50>
# malformed node or string: <_ast.Name object at 0x133c91310>
# malformed node or string: <_ast.Name object at 0x133e29dd0>
# malformed node or string: <_ast.Name object at 0x133c7c410>
# malformed node or string: <_ast.Name object at 0x133c7ce50>
# malformed node or string: <_ast.Name object at 0x133ca3a90>
# malformed node or string: <_ast.Name object at 0x133ca3810>
# malformed node or string: <_ast.Name object at 0x133caa590>
# malformed node or string: <_ast.Name object at 0x133ca0d10>
# malformed node or string: <_ast.Name object at 0x133cbfe90>
# malformed node or string: <_ast.Name object at 0x1cb4d27d0>
# malformed node or string: <_ast.Name object at 0x1cb7028d0>
# malformed node or string: <_ast.Name object at 0x1cb7eb490>
# malformed node or string: <_ast.Name object at 0x133c877d0>
# malformed node or string: <_ast.Name object at 0x1cb7cbad0>
# malformed node or string: <_ast.Name object at 0x1cb7c6a50>
# malformed node or string: <_ast.Name object at 0x1cb703190>
# malformed node or string: <_ast.Name object at 0x1cb7e5950>
# malformed node or string: <_ast.Name object at 0x1cb7ff110>
# malformed node or string: <_ast.Name object at 0x1cb563b10>
# malformed node or string: <_ast.Name object at 0x1cb4cb5d0>
# malformed node or string: <_ast.Name object at 0x133cd2590>
# malformed node or string: <_ast.Name object at 0x1cb561b90>
# malformed node or string: <_ast.Name object at 0x1c6990410>
# malformed node or string: <_ast.Name object at 0x1c69908d0>
# malformed node or string: <_ast.Name object at 0x1c6990110>
# malformed node or string: <_ast.Name object at 0x1c6954850>
# malformed node or string: <_ast.Name object at 0x1c6954bd0>
# malformed node or string: <_ast.Name object at 0x1c695e610>
# malformed node or string: <_ast.Name object at 0x1c6963890>
# malformed node or string: <_ast.Name object at 0x1c695fb10>
# malformed node or string: <_ast.Name object at 0x133f41d10>
# malformed node or string: <_ast.Name object at 0x133f41cd0>
# malformed node or string: <_ast.Name object at 0x133c9d4d0>
# malformed node or string: <_ast.Name object at 0x133c9d310>
# malformed node or string: <_ast.Name object at 0x133c9d550>
# malformed node or string: <_ast.Name object at 0x133cad410>
# malformed node or string: <_ast.Name object at 0x133cad8d0>
# malformed node or string: <_ast.Name object at 0x133c5e310>
# malformed node or string: <_ast.Name object at 0x133c5ef10>
# malformed node or string: <_ast.Name object at 0x133c5e250>
# malformed node or string: <_ast.Name object at 0x133e50d50>
# malformed node or string: <_ast.Name object at 0x133c5e7d0>
# malformed node or string: <_ast.Name object at 0x133cad850>
# malformed node or string: <_ast.Name object at 0x133c9d5d0>
# malformed node or string: <_ast.Name object at 0x133cbbe50>
# malformed node or string: <_ast.Name object at 0x133e310d0>
# malformed node or string: <_ast.Name object at 0x1c6961310>
# malformed node or string: <_ast.Name object at 0x1c695f810>
# malformed node or string: <_ast.Name object at 0x1c695c510>
# malformed node or string: <_ast.Name object at 0x1c6954cd0>
# malformed node or string: <_ast.Name object at 0x1c6990710>
# malformed node or string: <_ast.Name object at 0x1c6990610>
# malformed node or string: <_ast.Name object at 0x1cb4c2090>
# malformed node or string: <_ast.Name object at 0x133f64b50>
# malformed node or string: <_ast.Name object at 0x1cb7d1090>
# malformed node or string: <_ast.Name object at 0x1cb7ff110>
# malformed node or string: <_ast.Name object at 0x1cb7b9a10>
# malformed node or string: <_ast.Name object at 0x1c6967a90>
# malformed node or string: <_ast.Name object at 0x1cb711610>
# malformed node or string: <_ast.Name object at 0x133cc8250>
# malformed node or string: <_ast.Name object at 0x133ca24d0>
# malformed node or string: <_ast.Name object at 0x133ca3d10>
# malformed node or string: <_ast.Name object at 0x133c7ccd0>
# malformed node or string: <_ast.Name object at 0x133c91ad0>
# malformed node or string: <_ast.Name object at 0x1c696bb90>
# malformed node or string: <_ast.Name object at 0x1cb7e9710>
# malformed node or string: <_ast.Name object at 0x133c50d10>
# malformed node or string: <_ast.Name object at 0x133c50350>
# malformed node or string: <_ast.Name object at 0x133c50610>
# malformed node or string: <_ast.Name object at 0x133c50ad0>
# malformed node or string: <_ast.Name object at 0x1c6942cd0>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-a8cb89cd54cc> in <module>
#       3
#       4 # Plot the Overlay Map
# ----> 5 plot = generate_maps.plot_gdf(gdf, loc_gdf, filepath="/Users/thatcher/Desktop")
#
# ~/anaconda3/envs/pypack_eval/lib/python3.7/site-packages/libpypack/visualization/generate_maps.py in plot_gdf(gdf, loc_gdf, to_png, filepath)
#      45     basemap = gdf.plot(ax=ax, edgecolor='black')
#      46     loc_gdf.plot(ax=ax, marker='o', color='orange', markersize=250)
# ---> 47     plt.savefig(os.path.join(output_dir, "overlay_map.png"))
#      48     return loc_gdf.plot(ax=ax, marker='o', color='orange', markersize=250)
#      49
#
# NameError: name 'output_dir' is not defined

# %% [markdown]
# ### Webscraping URLs
# + webpage_locations.extract_webpage_locations(csv_file): You need to specify column_name to be the column you wish to scrape for content. This returns a datframe and a file named scraped_website_data.csv to the output_dir you specify.
# + webpage_locations.map_web_locations(web_df): Returns another Dataframe with the locations parsed and put into a column named "Web_Locs".

# %%
web_df = webpage_locations.extract_webpage_locations(csv_file, sep="\t", output_dir="/Users/thatcher/Desktop", column_name="URLs")
mapped_df = webpage_locations.map_web_locations(web_df, sep="\t", output_dir="/Users/thatcher/Desktop")
# Out:
# [SSL: KRB5_S_TKT_NYV] unexpected eof while reading (_ssl.c:2555)
# HTTP Error 403: Forbidden
# HTTP Error 403: Forbidden
# HTTP Error 403: Forbidden
# HTTP Error 404: Not Found
# URL can't contain control characters. "/Kath3853/status/1059193352585908230', 'https://twitter.com/Tko77457444/status/1059198355799240704', 'https://twitter.com/WwgQn/status/1059198596560683008" (found at least ' ')
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 403: Forbidden
# HTTP Error 403: Forbidden
# HTTP Error 403: Forbidden
# URL can't contain control characters. "/watch?v=Ix-V__nuazY', 'https://twitter.com/i/web/status/1058937614118670342" (found at least ' ')
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# URL can't contain control characters. "/AkwF6AyN6d4', 'https://www.instagram.com/p/BppeWubHbwH/?utm_source=ig_twitter_share&igshid=1v67gz3dwubil" (found at least ' ')
# HTTP Error 404: Not Found
# HTTP Error 403: Forbidden
# HTTP Error 404: Not Found

# %% [markdown]
# ### Plotting the Web Data
# + generate_maps.get_loc_gdf(mapped_df): Reading in the df with locations mapped (in this case mapped_df). Returns a GeoPandas DataFrame that can be used to generate the same maps as above. Just make sure to change the column to "Web_Locs" just like below!

# %%
# Generate the geoDataFrame with Lat/Lon Information
web_gdf = generate_maps.get_loc_gdf(mapped_df, column_name="Web_Locs")

# %%
# Generate the Location Overlay Map
web_gdf, web_loc_gdf = generate_maps.generate_overlay_gdf(mapped_df, filename="/Users/thatcher/Documents/GraduateSchool/Thesis/FORKS/PyPACK/libpypack/examples/states_21basic/states.shp", column_name="Web_Locs")

# Plot the Overlay Mapw
plot = generate_maps.plot_gdf(web_gdf, web_loc_gdf, filepath="/Users/thatcher/Desktop")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-3fa28d18c868> in <module>
#       3
#       4 # Plot the Overlay Mapw
# ----> 5 plot = generate_maps.plot_gdf(web_gdf, web_loc_gdf, filepath="/Users/thatcher/Desktop")
#       6
#
# ~/anaconda3/envs/pypack_eval/lib/python3.7/site-packages/libpypack/visualization/generate_maps.py in plot_gdf(gdf, loc_gdf, to_png, filepath)
#      45     basemap = gdf.plot(ax=ax, edgecolor='black')
#      46     loc_gdf.plot(ax=ax, marker='o', color='orange', markersize=250)
# ---> 47     plt.savefig(os.path.join(output_dir, "overlay_map.png"))
#      48     return loc_gdf.plot(ax=ax, marker='o', color='orange', markersize=250)
#      49
#
# NameError: name 'output_dir' is not defined

# %%
# Generate the heatmap
hmap = heatmap.heatmap(web_loc_gdf, output_dir="/Users/thatcher/Desktop")

# Display the heatmap
hmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Generate the Choropleth Map
new_web_gdf = choropleth.choropleth_map(web_loc_gdf, shp_path="/Users/thatcher/Documents/GraduateSchool/Thesis/FORKS/PyPACK/libpypack/examples/states_21basic/states.shp")

# Plot the choropleth map
plot = choropleth.plot_map(new_web_gdf, output_dir="/Users/thatcher/Desktop")
